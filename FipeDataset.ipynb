# %%
import pandas as pd
import sqlite3

# %%
con = sqlite3.connect('database.db')
df = pd.read_sql('SELECT * FROM fipe;', con)

# %%
df
# Out:
#         Valor   Marca                                     Modelo  AnoModelo  \
# 0       12129   Acura                             Integra GS 1.8       1992
# 1      163215     BMW                  135iA Coupé 3.0 24V 306cv       2011
# 2      248606     BMW  320iA Modern\/Sport TB 2.0\/A.Flex\/GP 4p       2020
# 3       32563     BMW                         323i\/iA Exclusive       2000
# 4       31357     BMW                     328i\/iA (novo modelo)       1999
# ...       ...     ...                                        ...        ...
# 53340    9543  Subaru                    Impreza GL 2.0 4x4 Mec.       1996
# 53341   37633  Subaru              Impreza SD WRX 2.0 16V TB 4x4       2002
# 53342   99425  Subaru             Impreza WRX STI 2.5 16V TB 4x4       2008
# 53343    7640  Subaru                    Legacy GL 2.0\/ GLS Mec       1995
# 53344    8953  Subaru                  Legacy GX TW 2.2 4x4 Aut.       1993
#
# ...
